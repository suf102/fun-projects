# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
def runtrials(diesize,num_trial,sample_sizes):
    die = range(1,diesize+1)
    samples = np.random.choice(die,size = [sample_sizes,num_trial])
    mean_results = np.mean(samples,axis=0)
    totalresults = samples.flatten()
    plt.hist(mean_results, bins=number_of_bins)
    plt.title(f" the mean values of {num_trial} trials of size {sample_sizes}")
    plt.show()
    plt.hist(totalresults,bins = number_of_bins)
    plt.title(f" Histogram of {num_trial*sample_sizes} samples from 6d6")
    plt.show()
    return

# %%
number_of_bins = 100

sample_size = 10
largenumber = 8
num_trails = 100000000
diesize = 100

runtrials(diesize,num_trails,sample_size)

# %%
def runtrials(diesize,num_trial,sample_sizes):
    die = range(1,diesize+1)
    samples = np.random.choice(die,size = [sample_sizes,num_trial])
    mean_results = np.sum(samples,axis=0)
    totalresults = samples.flatten()
    plt.hist(mean_results, bins=number_of_bins)
    plt.title(f" the mean values of {num_trial} trials of size {sample_sizes}")
    plt.show()
    plt.hist(totalresults,bins = number_of_bins)
    plt.title(f" Histogram of {num_trial*sample_sizes} samples from d36")
    plt.show()
    return

# %%
number_of_bins = 36

sample_size = 1
largenumber = 8
num_trails = 10000000
diesize = 36

runtrials(diesize,num_trails,sample_size)

# %%
def tenspalce(num):
    return (num -1)*6
 

def runtrials(diesize,num_trial,sample_sizes):
    die = range(1,diesize+1)
    nptensplace = np.vectorize(tenspalce)
    samples = np.add(nptensplace(np.random.choice(die,size = [sample_sizes,num_trial])),np.random.choice(die,size = [sample_sizes,num_trial]))
    totalresults = samples.flatten()
    plt.hist(totalresults,bins = number_of_bins)
    plt.title(f" Histogram of {num_trial*sample_sizes} samples from d36")
    plt.show()
    return

# %%
number_of_bins = 36

sample_size = 1
largenumber = 8
num_trails = 10000000
diesize = 6

runtrials(diesize,num_trails,sample_size)

# %%
def runtrials(diesize,num_trial,sample_sizes):
    die = range(1,diesize+1)
    samples = np.random.choice(die,size = [sample_sizes,num_trial])
    mean_results = np.sum(samples,axis=0)
    results = mean_results.flatten()
    secondaryresults= np.random.choice(results,size = [sample_sizes,num_trial] )
    return print(secondaryresults)

# %%
number_of_bins = 36

sample_size = 4
largenumber = 8
num_trails = 10000000
diesize = 6

runtrials(diesize,num_trails,sample_size)
# Out:
# [[16 11 12 ... 13 17 10]
#  [16 18 13 ... 13 14 13]
#  [11 12 18 ... 18 12 18]
#  [14 16  4 ... 11 11 15]]

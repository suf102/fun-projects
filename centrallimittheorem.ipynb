# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
def runtrials(num_trial,sample_sizes):
    samples = np.random.rand(sample_sizes,num_trails)
    mean_results = np.mean(samples,axis=0)
    totalresults = samples.flatten()
    plt.hist(mean_results, bins=number_of_bins)
    plt.title(f" the mean values of {num_trial} trials of size {sample_sizes}")
    plt.show()
    # plt.hist(totalresults,bins = number_of_bins)
    # plt.title(f" Histogram of {num_trial*sample_sizes} samples from the uniform distribution")
    # plt.show()
    return

# %%
number_of_bins = 100

sample_size = 10
largenumber = 8

for i in range(largenumber):
    num_trails = 10**i
    results = runtrials(num_trails,sample_size)
